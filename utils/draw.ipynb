# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
loss=np.load('loss.npy')

# %%
x=np.arange(len(loss))

plt.plot(x, loss)

# %%
loss=torch.load('/home/yaso/FL_CAE/experiments_FL/training/loss_train')

# %%
x=np.arange(len(loss['loss_train']))
plt.plot(x, loss['loss_train'])
